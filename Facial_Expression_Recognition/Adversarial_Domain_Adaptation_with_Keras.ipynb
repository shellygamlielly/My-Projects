# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Build Models

# %%
pip install keras_vggface
# Out:
# Collecting keras_vggface
#   Downloading https://files.pythonhosted.org/packages/2f/7d/5f0319ebdc09ac1a2272364fa9583f5067b6f8aff93fbbf8835d81cbaad7/keras_vggface-0.6-py3-none-any.whl
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras_vggface) (2.10.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras_vggface) (2.3.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from keras_vggface) (7.0.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras_vggface) (1.12.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras_vggface) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras_vggface) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras_vggface) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras_vggface) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras_vggface) (1.1.2)
# Installing collected packages: keras-vggface
# Successfully installed keras-vggface-0.6

# %%
import random
import numpy as np
from keras.models import Model
from keras.applications.resnet50 import ResNet50
from keras.layers import Input, Conv2D, MaxPool2D, Flatten, Dense,Reshape
from keras.layers import BatchNormalization, Activation, Dropout
from keras_vggface.vggface import VGGFace

def build_embedding(param, inp):
    network = eval('VGGFace')
    base = network(weights = 'vggface', include_top = False)
    feat = base(inp)
    print(feat.shape)
    flat = Flatten()(feat)
    return flat

def build_classifier(param, embedding):
    flat = Flatten()(embedding.output)
    dense1 = Dense(400, name = 'class_dense1')(flat)
    bn1 = BatchNormalization(name = 'class_bn1')(dense1)
    act1 = Activation('relu', name = 'class_act1')(bn1)
    drop2 = Dropout(param["drop_classifier"], name = 'class_drop1')(act1)

    dense2 = Dense(100, name = 'class_dense2')(drop2)
    bn2 = BatchNormalization(name = 'class_bn2')(dense2)
    act2 = Activation('relu', name = 'class_act2')(bn2)
    
    drop2 = Dropout(param["drop_classifier"], name = 'class_drop2')(act2)
    densel = Dense(param["number_of_classe"], name = 'class_dense_last')(drop2)
    bnl = BatchNormalization(name = 'class_bn_last')(densel)
    actl = Activation('softmax', name = 'class_act_last')(bnl)
    return Model(input=embedding, outputs=actl)

def build_discriminator(param, embedding):
    embedding = Input( embedding_shape )
    flat = Flatten()(embedding)
    dense1 = Dense(400, name = 'dis_dense1')(flat)
    bn1 = BatchNormalization(name='dis_bn1')(dense1)
    act1 = Activation('relu', name = 'dis_act1')(bn1)
    drop1 = Dropout(param["drop_discriminator"], name = 'dis_drop1')(act1)

    dense2 = Dense(100, name = 'dis_dense2')(drop1)
    bn2 = BatchNormalization(name='dis_bn2')(dense2)
    act2 = Activation('relu', name = 'dis_act2')(bn2)
    drop2 = Dropout(param["drop_discriminator"], name = 'dis_drop2')(act2)

    densel = Dense(1, name = 'dis_dense_last')(drop2)
    bnl = BatchNormalization(name = 'dis_bn_last')(densel)
    actl = Activation('sigmoid', name = 'dis_act_last')(bnl)
    return Model(input=embedding, outputs=actl)

def build_combined_classifier(inp, classifier):
    comb_model = Model(inputs = inp, outputs = [classifier])
    return comb_model

def build_combined_discriminator(inp, discriminator):
    comb_model = Model(inputs = inp, outputs = [discriminator])
    return comb_model

def build_combined_model(inp, comb):
    comb_model = Model(inputs = inp, outputs = comb)
    return comb_model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Optimizer

# %%
import numpy as np
from keras.optimizers import Adam

def opt_classifier(param):
    return Adam(lr=param["lr_classifier"], beta_1=param["b1_classifier"], beta_2=param["b2_classifier"])

def opt_discriminator(param):
    return Adam(lr=param["lr_discriminator"], beta_1=param["b1_discriminator"], beta_2=param["b2_discriminator"])

def opt_combined(param):
    return Adam(lr=param["lr_combined"], beta_1=param["b1_combined"], beta_2=param["b2_combined"])

# %% [markdown]
# # Load Data

# %%
SEED = 7
import os
import sys
import argparse
import random
import numpy as np
# import tensorflow.python.keras as tf
from tensorflow.compat.v1 import set_random_seed
# import tensorflow.python.keras as tf
from sklearn.model_selection import train_test_split
from sklearn import metrics
from plotnine import *
import pandas as pd
                
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from math import ceil
from sklearn.utils import shuffle as skshuffle

from imutils import paths
from sklearn.preprocessing import LabelEncoder

os.environ['PYTHONHASHSEED']=str(SEED)
np.random.seed(SEED)
set_random_seed(SEED)
random.seed(SEED)

from PIL import Image
from keras.utils import to_categorical
from keras.layers import Input
from keras.optimizers import Adam
from keras.utils import multi_gpu_model
from sklearn.metrics import accuracy_score
import pickle

from keras.preprocessing import image
def pil_loader(path):
    with open(path, 'rb') as f:
      with Image.open(f) as img:
        return img.convert('RGB')

def one_hot_encoding(param):
    lb = LabelEncoder()
    source_labels,target_labels  = lb.fit_transform( param["source_label"]),lb.fit_transform( param["target_label"])
    param["number_of_classe"] = len(lb.classes_)
    source_labels,target_labels = to_categorical(source_labels),to_categorical(target_labels)
    f = open('/content/drive/My Drive/pro_data/‏result_updated_gan_notB/labels',"wb")
    f.write(pickle.dumps(lb))
    f.close()
    return source_labels,target_labels

            
def data_loader(filepath, inp_dims):

    img = []
    label = []
    detector = dlib.get_frontal_face_detector()
    predictor = "drive/My Drive/final_proj_dataset/shape_predictor_5_face_landmarks.dat"
    imagePaths = sorted(list(paths.list_images(filepath)))
    # loop over the input images
    for imagePath in imagePaths:
        # extract the class label from the image path and update the
        # labels list
        l = imagePath.split(os.path.sep)[-2]
        label.append(l)
        # i = pil_loader(imagePath)
        i = image.load_img(imagePath)
        # keras.preprocessing.image.img_to_array(image)
        i = i.resize((inp_dims[0], inp_dims[1]), Image.ANTIALIAS)
        frame_1 = align_and_crop(detector, np.array(i), predictor)[0]
        frame_1 = cv2.resize(frame_1,(inp_dims[0], inp_dims[1]))
        img.append(frame_1)
    img = np.array(img)
    label = np.array(label)
    return img, label
    

def batch_generator(data, batch_size):
    #Generate batches of data.
    all_examples_indices = len(data[0])
    while True:
        mini_batch_indices = np.random.choice(all_examples_indices, size = batch_size, replace = False)
        tbr = [k[mini_batch_indices] for k in data]
        yield tbr

# %% [markdown]
# # Augment

# %%
from imgaug import augmenters as iaa
from imgaug import seed
def aug_training_set_loader(images,labels,inp_dims):
    NUM_COPIES = ceil(1000/len(images))
    images = np.array(images)
    images=augment(inp_dims[0], inp_dims[1], images, NUM_COPIES)
    aug_labels =[]
    for x in labels:
        for i in range(NUM_COPIES+1):  # NUM_COPIES+1-> numbers of augmentations + 1 original
            aug_labels.append(x)
    images, labels = skshuffle(images, aug_labels)
    images = np.array(images)
    # images = np.array(images, dtype="float") / 255.0
    labels = np.array(labels)
    return images, labels

def augment(width, height, data, NUM_COPIES):
    """
    preform augmentetion on the list of photos named 'data'
    :param width: width of a single photo
    :param height: height of a single photo
    :param data: a list of photos to augment
    :param NUM_COPIES: number of copies produced from the image
    :return: a list of photos that consists from the original photos and their augmentations
    """
    augmented_data = []
    sometimes = lambda aug: iaa.Sometimes(0.5, aug)
    seq = iaa.Sequential([
        sometimes(iaa.Sharpen(alpha=(0.0, 1.0), lightness=(0.75, 2.0))),
        sometimes(iaa.Fliplr()),  # horizontal flips
        sometimes(iaa.AddElementwise((-50, 50))),
        sometimes(iaa.Sometimes(0.5, iaa.GaussianBlur(sigma=(0.0, 2.0)))),
        sometimes(iaa.ContrastNormalization((0.8, 1.2))),
        sometimes(iaa.Multiply((0.8, 1.2), per_channel=0.2)),
        sometimes(iaa.Affine(
            scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
            translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
            shear=(-8, 8)
        )),
        sometimes(iaa.Superpixels(p_replace=0.1, n_segments=150))
    ], random_order=True)  # apply augmenters in random order
    for img in data:
        copies = augment_image(width, height, img, seq, NUM_COPIES)
        copies.append(img.reshape(width, height, 3))
        for cpy in copies:
            augmented_data.append(cpy)
    return augmented_data


def augment_image(width, height, image, seq, NUM_COPIES):
    """
        augments a single image
    :param width: width of the image
    :param height: height of the image
    :param image: a matrix representing a rgb image
    :param seq: the augmantation sequence preformed
    :param NUM_COPIES: number of copies produced from the image
    :return: a list of all images made from 'image' not including the original
    """
    seed (1)
    copies = []
    image = image.reshape(width, height, 3)
    for i in range(NUM_COPIES):
        copies.append(seq.augment_image(image))

    return copies

# %% [markdown]
# # Crop

# %%
import dlib

import os
import sys
import cv2
import glob

def align_and_crop(detector, im_to_align, predictor_path):
    '''
    simply aligns the photo (using the detector to identify the eyes) and crops the face.
    :param im_to_align: an address of an image
    '''

    # a shape predictor to find face landmarks so we can precisely localize the face
    sp = dlib.shape_predictor(predictor_path)

    # Ask the detector to find the bounding boxes of each face. The 1 in the
    # second argument indicates that we should upsample the image 1 time.
    try:
        dets = detector(im_to_align, 1)
    except RuntimeError:
        return -1

    num_faces = len(dets)
    if num_faces == 0:
        return im_to_align, False

    # Find the 5 face landmarks we need to do the alignment.
    faces = dlib.full_object_detections()
    for detection in dets:
        faces.append(sp(im_to_align, detection))

    # get a single chip (aligned and cropped)
    image = dlib.get_face_chip(im_to_align, faces[0])
    # cv2.imshow("f", image) show image for testing
    return image, True

# %% [markdown]
# # Train Combined Model

# %%
from keras.applications.vgg16 import preprocess_input
def train(param):
    models = {}
    inp = Input(shape = (param["inp_dims"]))
    embedding = build_embedding(param, inp) 
    # embedding = build_embedding(param)   
    
    # Build and compile the discriminator
    discriminator = build_discriminator(param, embedding)

    # The discriminator takes the representaton as input and determines the domain
    models["combined_discriminator"] = Model(inputs=inp, outputs=discriminator(embedding))
    models["combined_discriminator"].compile(optimizer = opt_discriminator(param), loss = 'binary_crossentropy', metrics = ['accuracy'])
    # For the combined model we will only train the generator
    discriminator.trainable = False
  
    # Build the classifier
    classifier = build_classifier(param, embedding)
    models['combined_classifier'] = Model(inputs=inp, outputs=classifier(embedding))
    models["combined_classifier"].compile(optimizer = opt_classifier(param), loss = 'categorical_crossentropy', metrics = ['accuracy'])

   
    models["combined_model"] = build_combined_model(inp, [classifier(embedding), discriminator(embedding)]) 
   
    models["combined_model"].compile(optimizer = opt_combined(param), loss = ['categorical_crossentropy', 'binary_crossentropy'] , loss_weights =  [param["class_loss_weight"],  param["dis_loss_weight"]], metrics = ['accuracy'])

    models["combined_classifier"].summary()
    models["combined_discriminator"].summary()
    models["combined_model"].summary()

    Xs, ys = param["source_data"], param["source_label"]
    Xt, yt = param["target_data"], param["target_label"]

    Xt, Xt_test, yt, yt_test = train_test_split(Xt, yt, test_size=0.4, random_state=42)
    Xs, Xs_test, ys, ys_test = train_test_split(Xs, ys, test_size=0.4, random_state=42)

    print("number of examples in training set source",Xs.shape[0] )
    print("number of examples in test set source",Xs_test.shape[0] )
    print("number of examples in training set target",Xt.shape[0] )
    print("number of examples in test set target",Xt_test.shape[0] )

    Xs_test = preprocess_input(Xs_test)
    Xt_test = preprocess_input(Xt_test)

    print("before augment")
    plt.imshow(Xs[0])
    plt.show()
    plt.imshow(Xt[0])
    plt.show()
    
    Xs, ys = aug_training_set_loader(Xs, ys, param["inp_dims"])
    Xt, yt = aug_training_set_loader(Xt, yt, param["inp_dims"])

    print("after augment")
    plt.imshow(Xs[0])
    plt.show()
    plt.imshow(Xt[0])
    plt.show()

    Xs = Xs.astype(np.float32)
    Xt = Xt.astype(np.float32)

    Xs = preprocess_input(Xs)
    Xt = preprocess_input(Xt)
    print("after preprocess")
    plt.imshow(Xs[0])
    plt.show()
    plt.imshow(Xt[0])
    plt.show()
    plt.imshow(Xt[1])
    plt.show()
    plt.imshow(Xt[2])
    plt.show()

    param["Xs_test"], ys_test = skshuffle( Xs_test, ys_test)
    param["Xt_test"], yt_test = skshuffle( Xt_test, yt_test)



    # Source domain is represented by label 0 and Target by 1
    ys_adv = np.array(([0.] * ys.shape[0]))
    yt_adv = np.array(([1.] * yt.shape[0]))

    y_advb_1 = np.array(([1] * param["batch_size"] + [0] * param["batch_size"])) # For gradient reversal
    y_advb_2 = np.array(([0] * param["batch_size"] + [1] * param["batch_size"]))
    weight_class = np.array(([1] * param["batch_size"] + [0] * param["batch_size"]))
    weight_adv = np.ones((param["batch_size"] * 2,))
    S_batches = batch_generator([Xs, ys], param["batch_size"])
    T_batches = batch_generator([Xt, np.zeros(shape = (len(Xt),))], param["batch_size"])

    param["target_accuracy"] = 0

    optim = {}
    optim["iter"] = 0
    optim["acc"] = ""
    optim["labels"] = np.array(Xt.shape[0],)
    gap_last_snap = 0

    acc_source=[]
    acc_target=[]
    acc_domain_source=[]
    acc_domain_target=[]
    loss_discriminator = []
    loss_classifier_source=[]

    t_domain_label = np.ones(( param["batch_size"], 1))
    s_domain_label = np.zeros(( param["batch_size"], 1))
    for i in range(param["num_iterations"]):        
        Xsb, ysb = next(S_batches)
        Xtb, ytb = next(T_batches)

        X_adv = np.concatenate([Xsb, Xtb])
        y_class = np.concatenate([ysb, np.zeros_like(ysb)])


        # if ((i+1 ) % 2 == 0 and i>90):
        d_loss = models["combined_discriminator"].train_on_batch(X_adv, [y_advb_2])
        # Train the generator (wants discriminator to mistake images domains)
        g_loss = models["combined_model"].train_on_batch(X_adv, [y_class, y_advb_1])


        if ((i + 1) % param["test_interval"] == 0):
            ys_pred = models["combined_classifier"].predict(Xs)
            yt_pred = models["combined_classifier"].predict(Xt)
            
            ys_adv_pred = models["combined_discriminator"].predict(Xs)
            yt_adv_pred = models["combined_discriminator"].predict(Xt)

            source_accuracy = accuracy_score(ys.argmax(1), ys_pred.argmax(1))              
            target_accuracy = accuracy_score(yt.argmax(1), yt_pred.argmax(1))
            source_domain_accuracy = accuracy_score(ys_adv, np.round(ys_adv_pred))              
            target_domain_accuracy = accuracy_score(yt_adv, np.round(yt_adv_pred))

            acc_source.append(source_accuracy)
            acc_target.append(target_accuracy)
            acc_domain_source.append(source_domain_accuracy)
            acc_domain_target.append(target_domain_accuracy)

            print(d_loss)
            print(g_loss)
            loss_discriminator.append(d_loss)
            loss_classifier_source.append(g_loss)

            log_str = "iter: {:05d}: \nLABEL CLASSIFICATION: source_accuracy: {:.5f}, target_accuracy: {:.5f}\
                    \nDOMAIN DISCRIMINATION: source_domain_accuracy: {:.5f}, target_domain_accuracy: {:.5f} \n"\
                                                         .format(i, source_accuracy*100, target_accuracy*100,
                                                      source_domain_accuracy*100, target_domain_accuracy*100)
            print(log_str)

            if param["target_accuracy"] < target_accuracy:              
                optim["iter"] = i
                optim["acc"] = log_str
                optim["labels"] = ys_pred.argmax(1)
                param["target_accuracy"] = target_accuracy
                models["combined_classifier"].save('/content/drive/My Drive/pro_data/‏result_updated_gan_notB/best_combined_classifier_10000_iter.h5')

        #         if (gap_last_snap >= param["snapshot_interval"]):
        #             gap_last_snap = 0
        #             np.save(os.path.join(param["output_path"],"yPred_{}".format(optim["iter"])), optim["labels"])
        #             open(os.path.join(param["output_path"], "acc_{}.txt".format(optim["iter"])), "w").write(optim["acc"])
        #         #     models["combined_classifier"].save(os.path.join(param["output_path"],"iter_{:05d}_model.h5".format(i)))
        # gap_last_snap = gap_last_snap + 1;
    
    # print(optim["iter"],optim["acc"],optim["labels"])
    models["combined_classifier"].save('/content/drive/My Drive/pro_data/‏result_updated_gan_notB/last_combined_classifier_10000_iter.h5')

    print("Source matrix: ",metrics.confusion_matrix(ys.argmax(1), ys_pred.argmax(1)))
    print("Target matrix: ",metrics.confusion_matrix(yt.argmax(1), yt_pred.argmax(1)))

    ys_test_pred = models["combined_classifier"].predict(Xs_test)
    yt_test_pred = models["combined_classifier"].predict(Xt_test)
    source_accuracy_test = accuracy_score(ys_test.argmax(1), ys_test_pred.argmax(1))              
    target_accuracy_test = accuracy_score(yt_test.argmax(1), yt_test_pred.argmax(1))

    print("source accuracy test",source_accuracy_test)
    print("target accuracy test",target_accuracy_test)

    print("Source matrix: ",metrics.confusion_matrix(ys_test.argmax(1), ys_test_pred.argmax(1)))
    print("Target matrix: ",metrics.confusion_matrix(yt_test.argmax(1), yt_test_pred.argmax(1)))


    N = np.arange(0,len(acc_source))

    plt.style.use("ggplot")
    plt.figure()
    plt.plot(N, np.array(acc_source), label="Source accuracy")
    plt.plot(N, np.array(acc_target), label="Target accuracy")
    plt.plot(N, np.array(acc_domain_source), label="Domain Source accuracy")
    plt.plot(N, np.array(acc_domain_target), label="Domain Target accuracy")
    plt.title("Training Accuracy of Source and Target ")
    plt.xlabel("Number of intervals")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()

    plt.style.use("ggplot")
    plt.figure()
    plt.plot(N, np.array(loss_classifier_source), label="Classifier Loss")
    plt.plot(N, np.array(loss_discriminator), label="Discriminator loss")
    plt.title("Training Loss of Source and Target ")
    plt.xlabel("Number of intervals")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

# %% [markdown]
# # Main

# %%
import argparse
if __name__ == "__main__":

    # Initialize parameters
    param = {}
    param["number_of_gpus"] = 1
    param["network_name"] = 'VGGFace'
    param["inp_dims"] = [224, 224, 3]
    param["num_iterations"] = 15000
    param["lr_classifier"] = 0.0001
    param["b1_classifier"] = 0.9
    param["b2_classifier"] = 0.999    
    param["lr_discriminator"] = 0.000001
    param["b1_discriminator"] =  0.9
    param["b2_discriminator"] = 0.999
    param["lr_combined"] = 0.00001
    param["b1_combined"] =  0.9
    param["b2_combined"] =  0.999       
    param["batch_size"] = int(32/2)
    param["class_loss_weight"] = 1
    param["dis_loss_weight"] = 4    
    param["drop_classifier"] = 0.25
    param["drop_discriminator"] = 0.25
    param["test_interval"] = 100
    param["source_path"] = '/content/drive/My Drive/pro_data/‏‏source_notB'
    param["target_path"] =  '/content/drive/My Drive/pro_data/‏‏target_notB'
    param["snapshot_interval"] = 500
    param["output_path"] = '/content/drive/My Drive/pro_data/‏result_updated_gan_notB'
    param["number_of_classe"] = 0

    # # Create directory for saving models and log files
    if not os.path.exists(param["output_path"]):
        os.mkdir(param["output_path"])

# %%
print("[INFO] loading images...")
# Load source and target data
param["source_data"], param["source_label"] = data_loader(param["source_path"], param["inp_dims"])
print("source images loaded")
print("number of images in source domain", param["source_data"].shape[0])
param["target_data"], param["target_label"] = data_loader(param["target_path"], param["inp_dims"])
print("target images loaded")
print("number of images in target domain", param["target_data"].shape[0])
# Encode labels into one-hot format
print("[INFO] Encode labels into one-hot format")
param["source_label"], param["target_label"] = one_hot_encoding(param)
# Out:
# [INFO] loading images...
# source images loaded
# number of images in source domain 1812
# target images loaded
# number of images in target domain 1812
# [INFO] Encode labels into one-hot format

# %%
# Train data
print("[INFO] training network...")
train(param)
# param["combined_classifier"].save('drive/My Drive/pro_data/result_vgg_notBmix/_source_model_less_layers.h5')
# Out:
# [INFO] training network...
# (None, 7, 7, 512)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:82: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("di..., inputs=Tensor("in...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("cl..., inputs=Tensor("in...)`
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# vggface_vgg16 (Model)        multiple                  14714688
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# model_8 (Model)              multiple                  10078120
# =================================================================
# Total params: 24,792,808
# Trainable params: 24,791,800
# Non-trainable params: 1,008
# _________________________________________________________________
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# vggface_vgg16 (Model)        multiple                  14714688
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# model_6 (Model)              multiple                  10077805
# =================================================================
# Total params: 34,869,296
# Trainable params: 24,791,491
# Non-trainable params: 10,077,805
# _________________________________________________________________
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# vggface_vgg16 (Model)           multiple             14714688    input_5[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 25088)        0           vggface_vgg16[1][0]
# __________________________________________________________________________________________________
# model_8 (Model)                 multiple             10078120    flatten_2[0][0]
# __________________________________________________________________________________________________
# model_6 (Model)                 multiple             10077805    flatten_2[0][0]
# ==================================================================================================
# Total params: 34,870,613
# Trainable params: 24,791,800
# Non-trainable params: 10,078,813
# __________________________________________________________________________________________________
# number of examples in training set source 1087
# number of examples in test set source 725
# number of examples in training set target 1087
# number of examples in test set target 725
# before augment
# after augment
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# after preprocess
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [0.34255737, 1.0]
# [5.4269447, 0.28825957, 1.2846713, 0.46875, 0.0]
# iter: 00099:
# LABEL CLASSIFICATION: source_accuracy: 93.60626, target_accuracy: 28.01288
# DOMAIN DISCRIMINATION: source_domain_accuracy: 99.44802, target_domain_accuracy: 99.35603
#
# [0.32750025, 1.0]
# [5.435029, 0.23544788, 1.2998953, 0.59375, 0.0]
# iter: 00199:
# LABEL CLASSIFICATION: source_accuracy: 97.42410, target_accuracy: 27.69089
# DOMAIN DISCRIMINATION: source_domain_accuracy: 99.95400, target_domain_accuracy: 99.58602
#
# [0.323695, 1.0]
# [5.438807, 0.22206083, 1.3041866, 0.65625, 0.0]
# iter: 00299:
# LABEL CLASSIFICATION: source_accuracy: 97.70009, target_accuracy: 28.84085
# DOMAIN DISCRIMINATION: source_domain_accuracy: 99.95400, target_domain_accuracy: 99.86201
#
# [0.32985437, 1.0]
# [5.5080876, 0.31512854, 1.2982398, 0.53125, 0.0]
# iter: 00399:
# LABEL CLASSIFICATION: source_accuracy: 98.11408, target_accuracy: 22.40110
# DOMAIN DISCRIMINATION: source_domain_accuracy: 99.95400, target_domain_accuracy: 99.86201
#
# [0.31863958, 1.0]
# [5.4327703, 0.19292785, 1.3099606, 0.53125, 0.0]
# iter: 00499:
# LABEL CLASSIFICATION: source_accuracy: 97.97608, target_accuracy: 27.04692
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 99.95400
#
# [0.3234303, 1.0]
# [5.412273, 0.1888974, 1.3058438, 0.65625, 0.0]
# iter: 00599:
# LABEL CLASSIFICATION: source_accuracy: 98.25207, target_accuracy: 30.35879
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3250763, 1.0]
# [5.4046, 0.18627341, 1.3045816, 0.5625, 0.0]
# iter: 00699:
# LABEL CLASSIFICATION: source_accuracy: 98.39006, target_accuracy: 31.83073
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.32332253, 1.0]
# [5.445186, 0.21745715, 1.3069322, 0.59375, 0.0]
# iter: 00799:
# LABEL CLASSIFICATION: source_accuracy: 98.43606, target_accuracy: 25.29899
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.31792128, 1.0]
# [5.6455045, 0.39447343, 1.3127577, 0.5625, 0.0]
# iter: 00899:
# LABEL CLASSIFICATION: source_accuracy: 98.57406, target_accuracy: 21.66513
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3141216, 1.0]
# [5.470058, 0.20193335, 1.3170311, 0.5, 0.0]
# iter: 00999:
# LABEL CLASSIFICATION: source_accuracy: 98.57406, target_accuracy: 26.95492
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.31562525, 1.0]
# [5.456559, 0.19235535, 1.316051, 0.6875, 0.0]
# iter: 01099:
# LABEL CLASSIFICATION: source_accuracy: 98.52806, target_accuracy: 22.81509
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3152407, 1.0]
# [5.540068, 0.2723784, 1.3169224, 0.59375, 0.0]
# iter: 01199:
# LABEL CLASSIFICATION: source_accuracy: 98.62006, target_accuracy: 24.51702
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.31756568, 1.0]
# [5.446956, 0.18715242, 1.314951, 0.65625, 0.0]
# iter: 01299:
# LABEL CLASSIFICATION: source_accuracy: 98.57406, target_accuracy: 26.95492
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.31341326, 1.0]
# [5.5519433, 0.27305642, 1.3197217, 0.5, 0.0]
# iter: 01399:
# LABEL CLASSIFICATION: source_accuracy: 98.57406, target_accuracy: 31.64673
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.31631434, 1.0]
# [5.458687, 0.18928573, 1.3173503, 0.5625, 0.0]
# iter: 01499:
# LABEL CLASSIFICATION: source_accuracy: 98.80405, target_accuracy: 24.37902
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3127533, 1.0]
# [5.5311065, 0.24625407, 1.3212131, 0.625, 0.0]
# iter: 01599:
# LABEL CLASSIFICATION: source_accuracy: 98.52806, target_accuracy: 23.50506
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.31660572, 1.0]
# [5.4579897, 0.18618579, 1.317951, 0.6875, 0.0]
# iter: 01699:
# LABEL CLASSIFICATION: source_accuracy: 98.75805, target_accuracy: 18.12328
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3158533, 1.0]
# [5.5051556, 0.22932017, 1.3189589, 0.59375, 0.0]
# iter: 01799:
# LABEL CLASSIFICATION: source_accuracy: 98.57406, target_accuracy: 17.34131
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.31188843, 1.0]
# [5.5112095, 0.2169199, 1.3235724, 0.625, 0.0]
# iter: 01899:
# LABEL CLASSIFICATION: source_accuracy: 98.66605, target_accuracy: 26.90892
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.31480935, 1.0]
# [5.481965, 0.19862756, 1.3208344, 0.53125, 0.0]
# iter: 01999:
# LABEL CLASSIFICATION: source_accuracy: 98.71205, target_accuracy: 30.17479
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.31397027, 1.0]
# [5.5061812, 0.21719852, 1.3222457, 0.6875, 0.0]
# iter: 02099:
# LABEL CLASSIFICATION: source_accuracy: 98.52806, target_accuracy: 27.73689
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.31112623, 1.0]
# [5.4963183, 0.19328302, 1.3257588, 0.65625, 0.0]
# iter: 02199:
# LABEL CLASSIFICATION: source_accuracy: 98.66605, target_accuracy: 21.48114
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.311068, 1.0]
# [5.547949, 0.24301693, 1.326233, 0.6875, 0.0]
# iter: 02299:
# LABEL CLASSIFICATION: source_accuracy: 98.75805, target_accuracy: 27.69089
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3105124, 1.0]
# [5.543713, 0.23411226, 1.3274002, 0.65625, 0.0]
# iter: 02399:
# LABEL CLASSIFICATION: source_accuracy: 98.85005, target_accuracy: 18.90524
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.31268018, 1.0]
# [5.474687, 0.1729064, 1.3254452, 0.625, 0.0]
# iter: 02499:
# LABEL CLASSIFICATION: source_accuracy: 98.75805, target_accuracy: 24.97700
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.31144446, 1.0]
# [5.4886403, 0.17988603, 1.3271886, 0.5625, 0.0]
# iter: 02599:
# LABEL CLASSIFICATION: source_accuracy: 98.80405, target_accuracy: 33.11868
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.31067753, 1.0]
# [5.472521, 0.15842032, 1.3285252, 0.65625, 0.0]
# iter: 02699:
# LABEL CLASSIFICATION: source_accuracy: 98.80405, target_accuracy: 17.80129
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30926824, 1.0]
# [5.5261235, 0.20414014, 1.3304958, 0.5625, 0.0]
# iter: 02799:
# LABEL CLASSIFICATION: source_accuracy: 98.80405, target_accuracy: 32.19871
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30981034, 1.0]
# [5.500197, 0.17884701, 1.3303375, 0.625, 0.0]
# iter: 02899:
# LABEL CLASSIFICATION: source_accuracy: 98.80405, target_accuracy: 32.24471
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30973035, 1.0]
# [5.556497, 0.23273034, 1.3309417, 0.53125, 0.0]
# iter: 02999:
# LABEL CLASSIFICATION: source_accuracy: 98.85005, target_accuracy: 25.29899
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30976337, 1.0]
# [5.495488, 0.17038319, 1.3312763, 0.71875, 0.0]
# iter: 03099:
# LABEL CLASSIFICATION: source_accuracy: 98.75805, target_accuracy: 27.41490
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3113386, 1.0]
# [5.5283933, 0.20802689, 1.3300916, 0.59375, 0.0]
# iter: 03199:
# LABEL CLASSIFICATION: source_accuracy: 98.75805, target_accuracy: 21.75713
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.31068733, 1.0]
# [5.4986486, 0.17391106, 1.3311844, 0.59375, 0.0]
# iter: 03299:
# LABEL CLASSIFICATION: source_accuracy: 98.85005, target_accuracy: 25.71297
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30724713, 1.0]
# [5.5532904, 0.2122603, 1.3352575, 0.59375, 0.0]
# iter: 03399:
# LABEL CLASSIFICATION: source_accuracy: 98.85005, target_accuracy: 36.47654
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3057732, 1.0]
# [5.5355597, 0.18605423, 1.3373764, 0.6875, 0.0]
# iter: 03499:
# LABEL CLASSIFICATION: source_accuracy: 98.85005, target_accuracy: 27.78289
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30683768, 1.0]
# [5.52942, 0.18298918, 1.3366077, 0.59375, 0.0]
# iter: 03599:
# LABEL CLASSIFICATION: source_accuracy: 98.89604, target_accuracy: 24.88500
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3064999, 1.0]
# [5.541763, 0.19194764, 1.3374538, 0.6875, 0.0]
# iter: 03699:
# LABEL CLASSIFICATION: source_accuracy: 98.89604, target_accuracy: 25.62098
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3071455, 1.0]
# [5.548938, 0.19991574, 1.3372555, 0.625, 0.0]
# iter: 03799:
# LABEL CLASSIFICATION: source_accuracy: 98.75805, target_accuracy: 28.24287
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30913937, 1.0]
# [5.559495, 0.2163403, 1.3357887, 0.625, 0.0]
# iter: 03899:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 26.31095
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30625075, 1.0]
# [5.563003, 0.2065519, 1.3391128, 0.5625, 0.0]
# iter: 03999:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 32.29071
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30683368, 1.0]
# [5.5307493, 0.17455783, 1.3390479, 0.53125, 0.0]
# iter: 04099:
# LABEL CLASSIFICATION: source_accuracy: 98.89604, target_accuracy: 37.85649
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30601, 1.0]
# [5.551922, 0.19060335, 1.3403296, 0.59375, 0.0]
# iter: 04199:
# LABEL CLASSIFICATION: source_accuracy: 98.80405, target_accuracy: 22.40110
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3050219, 1.0]
# [5.5521307, 0.18488127, 1.3418124, 0.6875, 0.0]
# iter: 04299:
# LABEL CLASSIFICATION: source_accuracy: 98.80405, target_accuracy: 21.66513
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3051023, 1.0]
# [5.547321, 0.17845777, 1.3422158, 0.5625, 0.0]
# iter: 04399:
# LABEL CLASSIFICATION: source_accuracy: 98.89604, target_accuracy: 33.11868
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30472898, 1.0]
# [5.542971, 0.17078602, 1.3430463, 0.6875, 0.0]
# iter: 04499:
# LABEL CLASSIFICATION: source_accuracy: 98.85005, target_accuracy: 26.03496
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3045578, 1.0]
# [5.5581174, 0.18332106, 1.3436991, 0.6875, 0.0]
# iter: 04599:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 28.65685
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30392194, 1.0]
# [5.5724835, 0.1935954, 1.344722, 0.5625, 0.0]
# iter: 04699:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 17.20331
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3027575, 1.0]
# [5.635797, 0.2498588, 1.3464845, 0.53125, 0.0]
# iter: 04799:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 13.20147
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30241674, 1.0]
# [5.585464, 0.19650133, 1.3472407, 0.65625, 0.0]
# iter: 04899:
# LABEL CLASSIFICATION: source_accuracy: 98.80405, target_accuracy: 26.08096
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3042489, 1.0]
# [5.566087, 0.18229012, 1.3459492, 0.59375, 0.0]
# iter: 04999:
# LABEL CLASSIFICATION: source_accuracy: 98.89604, target_accuracy: 19.08924
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30151218, 1.0]
# [5.547612, 0.15076295, 1.3492123, 0.59375, 0.0]
# iter: 05099:
# LABEL CLASSIFICATION: source_accuracy: 98.85005, target_accuracy: 21.89512
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30313516, 1.0]
# [5.5709496, 0.17909412, 1.3479638, 0.59375, 0.0]
# iter: 05199:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 27.69089
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30200323, 1.0]
# [5.5816054, 0.18305045, 1.3496387, 0.5625, 0.0]
# iter: 05299:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 23.59706
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30118892, 1.0]
# [5.570843, 0.16696468, 1.3509697, 0.5625, 0.0]
# iter: 05399:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 17.75529
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30113903, 1.0]
# [5.57601, 0.1704604, 1.3513875, 0.6875, 0.0]
# iter: 05499:
# LABEL CLASSIFICATION: source_accuracy: 98.89604, target_accuracy: 27.69089
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30195752, 1.0]
# [5.5708604, 0.16677177, 1.3510221, 0.59375, 0.0]
# iter: 05599:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 23.18307
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3022172, 1.0]
# [5.602793, 0.19788417, 1.3512273, 0.5625, 0.0]
# iter: 05699:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 20.42318
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3007093, 1.0]
# [5.614782, 0.20170084, 1.3532703, 0.5625, 0.0]
# iter: 05799:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 23.36707
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.3009081, 1.0]
# [5.5761003, 0.16208097, 1.3535049, 0.53125, 0.0]
# iter: 05899:
# LABEL CLASSIFICATION: source_accuracy: 98.85005, target_accuracy: 30.58878
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29937434, 1.0]
# [5.641177, 0.21864033, 1.3556342, 0.625, 0.0]
# iter: 05999:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 21.57314
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30101725, 1.0]
# [5.5749297, 0.15779386, 1.3542839, 0.53125, 0.0]
# iter: 06099:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 33.21067
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.30011338, 1.0]
# [5.5860977, 0.16371463, 1.3555958, 0.6875, 0.0]
# iter: 06199:
# LABEL CLASSIFICATION: source_accuracy: 98.89604, target_accuracy: 20.37718
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29897648, 1.0]
# [5.693421, 0.26378965, 1.3574078, 0.53125, 0.0]
# iter: 06299:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 18.72125
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.2999165, 1.0]
# [5.604594, 0.1768823, 1.356928, 0.5625, 0.0]
# iter: 06399:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 32.06072
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29821444, 1.0]
# [5.606327, 0.16951337, 1.3592035, 0.625, 0.0]
# iter: 06499:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 34.91260
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29790425, 1.0]
# [5.598095, 0.15833363, 1.3599403, 0.71875, 0.0]
# iter: 06599:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 30.63477
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29865438, 1.0]
# [5.595266, 0.15722397, 1.3595104, 0.65625, 0.0]
# iter: 06699:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 30.49678
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29917073, 1.0]
# [5.642112, 0.20400244, 1.3595273, 0.5625, 0.0]
# iter: 06799:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 29.94480
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29790217, 1.0]
# [5.6434793, 0.19819638, 1.3613207, 0.5625, 0.0]
# iter: 06899:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 27.27691
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29861933, 1.0]
# [5.630698, 0.18680274, 1.3609738, 0.59375, 0.0]
# iter: 06999:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 18.95124
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29762536, 1.0]
# [5.6591644, 0.20892292, 1.3625604, 0.71875, 0.0]
# iter: 07099:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 17.15731
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29773712, 1.0]
# [5.655968, 0.20431164, 1.3629141, 0.5625, 0.0]
# iter: 07199:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 16.88132
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29744765, 1.0]
# [5.653953, 0.19907996, 1.3637183, 0.625, 0.0]
# iter: 07299:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 29.11684
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29573435, 1.0]
# [5.6401687, 0.17610684, 1.3660154, 0.59375, 0.0]
# iter: 07399:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 34.91260
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29620036, 1.0]
# [5.630333, 0.16678965, 1.3658859, 0.625, 0.0]
# iter: 07499:
# LABEL CLASSIFICATION: source_accuracy: 98.89604, target_accuracy: 30.49678
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29525173, 1.0]
# [5.6580524, 0.18829127, 1.3674403, 0.5625, 0.0]
# iter: 07599:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 26.81693
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.2957834, 1.0]
# [5.619273, 0.15013227, 1.3672853, 0.5625, 0.0]
# iter: 07699:
# LABEL CLASSIFICATION: source_accuracy: 98.89604, target_accuracy: 16.55934
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.2952302, 1.0]
# [5.631469, 0.15787403, 1.3683987, 0.71875, 0.0]
# iter: 07799:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 17.29531
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29584345, 1.0]
# [5.6589284, 0.1864493, 1.3681197, 0.6875, 0.0]
# iter: 07899:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 30.31279
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.294984, 1.0]
# [5.6476107, 0.169446, 1.3695412, 0.5625, 0.0]
# iter: 07999:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 22.30911
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.2938305, 1.0]
# [5.6697855, 0.18452653, 1.3713148, 0.5625, 0.0]
# iter: 08099:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 32.01472
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29498282, 1.0]
# [5.674826, 0.19307922, 1.3704368, 0.6875, 0.0]
# iter: 08199:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 43.65225
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29453912, 1.0]
# [5.6571136, 0.17150465, 1.3714023, 0.65625, 0.0]
# iter: 08299:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 22.63109
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29397362, 1.0]
# [5.6889114, 0.19885337, 1.3725145, 0.53125, 0.0]
# iter: 08399:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 26.12695
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.2930758, 1.0]
# [5.660696, 0.16490674, 1.3739474, 0.625, 0.0]
# iter: 08499:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 37.99448
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29336596, 1.0]
# [5.6694613, 0.17298204, 1.3741198, 0.59375, 0.0]
# iter: 08599:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 25.80497
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29281163, 1.0]
# [5.6706614, 0.17001626, 1.3751613, 0.6875, 0.0]
# iter: 08699:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 30.12879
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29506406, 1.0]
# [5.664413, 0.17217472, 1.3730595, 0.5625, 0.0]
# iter: 08799:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 23.22907
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29331505, 1.0]
# [5.754224, 0.25227803, 1.3754865, 0.59375, 0.0]
# iter: 08899:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 33.85465
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29266256, 1.0]
# [5.736216, 0.22951359, 1.3766756, 0.59375, 0.0]
# iter: 08999:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 31.50874
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29171687, 1.0]
# [5.6734524, 0.16053984, 1.3782282, 0.5625, 0.0]
# iter: 09099:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 33.21067
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29142112, 1.0]
# [5.752929, 0.23686439, 1.3790162, 0.5625, 0.0]
# iter: 09199:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 32.79669
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29070184, 1.0]
# [5.728939, 0.20774269, 1.3802991, 0.5625, 0.0]
# iter: 09299:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 32.42870
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29076052, 1.0]
# [5.7198277, 0.19701794, 1.3807024, 0.71875, 0.0]
# iter: 09399:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 23.09108
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.2909329, 1.0]
# [5.680771, 0.15709494, 1.380919, 0.59375, 0.0]
# iter: 09499:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 40.89236
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.2906971, 1.0]
# [5.698476, 0.17169842, 1.3816943, 0.65625, 0.0]
# iter: 09599:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 28.19687
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29028505, 1.0]
# [5.6924624, 0.162071, 1.3825978, 0.6875, 0.0]
# iter: 09699:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 17.84729
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29019028, 1.0]
# [5.6887636, 0.15625967, 1.383126, 0.59375, 0.0]
# iter: 09799:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 31.00276
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29110986, 1.0]
# [5.7334247, 0.20316133, 1.3825659, 0.75, 0.0]
# iter: 09899:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 37.90248
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28969657, 1.0]
# [5.733875, 0.19530345, 1.3846428, 0.53125, 0.0]
# iter: 09999:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 21.75713
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.29070154, 1.0]
# [5.715964, 0.18013054, 1.3839583, 0.53125, 0.0]
# iter: 10099:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 15.73137
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.2900238, 1.0]
# [5.706083, 0.16531305, 1.3851924, 0.5625, 0.0]
# iter: 10199:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 32.52070
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28882623, 1.0]
# [5.7168045, 0.1686644, 1.387035, 0.625, 0.0]
# iter: 10299:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 28.51886
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.2885984, 1.0]
# [5.7267528, 0.17593434, 1.3877046, 0.5625, 0.0]
# iter: 10399:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 19.64121
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28788966, 1.0]
# [5.725283, 0.16930257, 1.3889952, 0.8125, 0.0]
# iter: 10499:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 24.14903
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28719848, 1.0]
# [5.746548, 0.18548422, 1.390266, 0.53125, 0.0]
# iter: 10599:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 16.19135
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28939006, 1.0]
# [5.7258754, 0.17294101, 1.3882335, 0.65625, 0.0]
# iter: 10699:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 21.06716
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28710467, 1.0]
# [5.7132683, 0.14815336, 1.3912787, 0.59375, 0.0]
# iter: 10799:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 12.97148
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28725958, 1.0]
# [5.7862816, 0.21996039, 1.3915803, 0.6875, 0.0]
# iter: 10899:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 26.95492
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28645915, 1.0]
# [5.7552347, 0.18351832, 1.3929291, 0.5625, 0.0]
# iter: 10999:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 31.37075
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28700525, 1.0]
# [5.7634892, 0.19223115, 1.3928145, 0.6875, 0.0]
# iter: 11099:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 26.95492
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28653497, 1.0]
# [5.751486, 0.17637631, 1.3937774, 0.5625, 0.0]
# iter: 11199:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 31.09476
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28680676, 1.0]
# [5.7444253, 0.16880661, 1.3939047, 0.5625, 0.0]
# iter: 11299:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 26.81693
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.2851608, 1.0]
# [5.7848573, 0.19977354, 1.396271, 0.5625, 0.0]
# iter: 11399:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 27.50690
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28623143, 1.0]
# [5.845223, 0.26314402, 1.3955197, 0.71875, 0.0]
# iter: 11499:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 25.25299
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28606057, 1.0]
# [5.7494574, 0.16473669, 1.3961802, 0.5625, 0.0]
# iter: 11599:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 31.73873
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28611296, 1.0]
# [5.7478, 0.16148224, 1.3965794, 0.53125, 0.0]
# iter: 11699:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 22.07912
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28408295, 1.0]
# [5.788187, 0.19076735, 1.3993549, 0.5625, 0.0]
# iter: 11799:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 23.87305
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28497106, 1.0]
# [5.744155, 0.14893812, 1.3988042, 0.5625, 0.0]
# iter: 11899:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 22.17111
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28564128, 1.0]
# [5.795529, 0.2014228, 1.3985265, 0.625, 0.0]
# iter: 11999:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 32.98068
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.284667, 1.0]
# [5.7472563, 0.14690039, 1.400089, 0.5, 0.0]
# iter: 12099:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 30.35879
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.2841364, 1.0]
# [5.77836, 0.1737178, 1.4011605, 0.53125, 0.0]
# iter: 12199:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 18.35327
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28400475, 1.0]
# [5.7720113, 0.16471231, 1.4018247, 0.59375, 0.0]
# iter: 12299:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 25.94296
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28383413, 1.0]
# [5.766788, 0.1569627, 1.4024563, 0.5625, 0.0]
# iter: 12399:
# LABEL CLASSIFICATION: source_accuracy: 98.98804, target_accuracy: 29.07084
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.2823307, 1.0]
# [5.775734, 0.15711242, 1.4046553, 0.59375, 0.0]
# iter: 12499:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 33.11868
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# [0.28265625, 1.0]
# [5.7910924, 0.17221977, 1.4047182, 0.53125, 0.0]
# iter: 12599:
# LABEL CLASSIFICATION: source_accuracy: 98.94204, target_accuracy: 29.85281
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# Source matrix:  [[446   0   6   0]
#  [  0 448   0   0]
#  [ 17   0 631   0]
#  [  0   0   0 626]]
# Target matrix:  [[  0  34 300 118]
#  [  0   1 327 120]
#  [  1  13 616  18]
#  [  2 155 437  32]]
# source accuracy test 0.9475862068965517
# target accuracy test 0.2675862068965517
# Source matrix:  [[148   0   7   0]
#  [  0 157   0   0]
#  [ 27   0 174   0]
#  [  1   0   3 208]]
# Target matrix:  [[  0  18  99  38]
#  [  0   1 115  41]
#  [  5  10 182   4]
#  [  3  54 144  11]]

# %%
import keras
path = '/content/drive/My Drive/pro_data/‏result_updated_gan_notB/best_combined_classifier_10000_iter.h5'

model = keras.models.load_model(path)

# %%
ys_test_pred = model.predict(param["source_data"])
yt_test_pred = model.predict(param["target_data"])
ys_test = param["source_label"]
yt_test = param["target_label"]
source_accuracy_test = accuracy_score(ys_test.argmax(1), ys_test_pred.argmax(1))              
target_accuracy_test = accuracy_score(yt_test.argmax(1), yt_test_pred.argmax(1))

print("source accuracy test",source_accuracy_test)
print("target accuracy test",target_accuracy_test)

print("Source matrix: ",metrics.confusion_matrix(ys_test.argmax(1), ys_test_pred.argmax(1)))
print("Target matrix: ",metrics.confusion_matrix(yt_test.argmax(1), yt_test_pred.argmax(1)))
# Out:
# source accuracy test 0.9729580573951435
# target accuracy test 0.4216335540838852
# Source matrix:  [[369   1  11   0]
#  [  0 381   0   0]
#  [ 33   1 491   0]
#  [  1   1   1 522]]
# Target matrix:  [[ 20  83 170 108]
#  [ 57 186  89  49]
#  [ 85  24 131 285]
#  [ 16  51  31 427]]
